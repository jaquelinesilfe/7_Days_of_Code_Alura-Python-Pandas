# %%
import pandas as pd

# %% [markdown]
# #### Importando arquivos

# %%
dados_2010_1 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20101.csv')
dados_2010_2 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20102.csv')
dados_2011_1 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20111.csv')
dados_2011_2 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20112.csv')
dados_2012_1 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20121.csv')
dados_2012_2 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20122.csv')
dados_2013_1 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20131.csv')
dados_2013_2 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20132.csv')
dados_2014_1 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20141.csv')
dados_2014_2 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20142.csv')
dados_2015_1 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20151.csv')
dados_2015_2 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20152.csv')
dados_2016_1 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20161.csv')
dados_2016_2 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20162.csv')
dados_2017_1 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20171.csv')
dados_2017_2 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20172.csv')
dados_2018_1 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20181.csv')
dados_2018_2 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20182.csv')
dados_2019_1 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20191.csv')
dados_2019_2 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20192.csv')
dados_2020_1 = pd.read_csv('dataset\dados_emprestimos\emprestimos-20201.csv')

# %% [markdown]
# #### Concatenando os arquivos

# %%
emprestimos_biblioteca = pd.concat([dados_2010_1,dados_2010_2,dados_2011_1,dados_2011_2,dados_2012_1,dados_2012_2,dados_2013_1,dados_2013_2,dados_2014_1,
                                    dados_2014_2,dados_2015_1,dados_2015_2,dados_2016_1,dados_2016_2,dados_2017_1,dados_2017_2,dados_2018_1,dados_2018_2,
                                    dados_2019_1,dados_2019_2,dados_2020_1],ignore_index=True)
emprestimos_biblioteca
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1        2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2        2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3        2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...                                ...                            ...
# 2258013  2020/05/05 19:51:06.059000000  2021/05/13 14:53:31.000000000
# 2258014  2020/05/05 19:51:06.135000000  2021/05/13 14:53:38.000000000
# 2258015  2020/05/05 19:51:06.164000000  2021/05/13 15:01:46.000000000
# 2258016  2020/06/09 11:54:02.669000000  2021/07/21 15:33:55.000000000
# 2258017  2020/06/09 11:54:02.852000000  2021/07/21 15:33:45.000000000
#
#          matricula_ou_siape             tipo_vinculo_usuario
# 0              2.008023e+09               ALUNO DE GRADUAÇÃO
# 1              2.008023e+09               ALUNO DE GRADUAÇÃO
# 2              2.008112e+09           ALUNO DE PÓS-GRADUAÇÃO
# 3              2.007211e+08               ALUNO DE GRADUAÇÃO
# 4              2.008023e+09               ALUNO DE GRADUAÇÃO
# ...                     ...                              ...
# 2258013        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2258014        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2258015        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2258016        2.020101e+10           ALUNO DE PÓS-GRADUAÇÃO
# 2258017        2.020101e+10           ALUNO DE PÓS-GRADUAÇÃO
#
# [2258018 rows x 7 columns]

# %% [markdown]
# ### Verificando duplicatas

# %%
emprestimos_biblioteca.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# 2461099        2012008348     2016/06/27 20:35:46.855000000  2016/06/14 11:20:33.254000000  2016/07/11 14:37:29.000000000  2.015022e+09        ALUNO DE GRADUAÇÃO        2
#                                                                                                                                                                         ..
# 1443389        2011018954     2013/03/22 13:18:55.037000000  2013/03/07 11:21:26.480000000  2013/04/08 20:26:07.000000000  2.010046e+09        ALUNO DE GRADUAÇÃO        1
# 1443390        2009056314     2013/03/21 09:28:45.689000000  2013/03/07 11:21:28.899000000  2013/04/05 18:18:00.000000000  2.011015e+09        ALUNO DE GRADUAÇÃO        1
# 1443393        2012037906     2013/03/20 20:17:10.574000000  2013/03/07 11:24:19.326000000  2013/03/25 08:58:44.000000000  2.011038e+09        ALUNO DE GRADUAÇÃO        1
# 1443395        2011033069     2013/04/07 01:06:51.679000000  2013/03/07 11:25:22.661000000  2013/05/07 16:19:34.000000000  2.011106e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 10322328       2014070441     2018/01/15 12:26:00.697000000  2017/12/29 18:21:09.060000000  2018/01/31 18:50:25.000000000  2.014063e+09        ALUNO DE GRADUAÇÃO        1
# Length: 968028, dtype: int64

# %% [markdown]
# ### Excluindo Duplicatas

# %%
emprestimos_biblioteca = emprestimos_biblioteca.drop_duplicates()

# %%
emprestimos_biblioteca.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 2336122        2011033079     2016/11/21 02:01:58.488000000  2016/11/10 17:00:12.989000000  2016/12/02 14:21:49.000000000  2.016023e+09        ALUNO DE GRADUAÇÃO        1
# 2336103        2014085936     2016/11/25 19:25:36.215000000  2016/11/10 16:54:52.447000000  2016/12/13 14:30:52.000000000  2.014047e+09        ALUNO DE GRADUAÇÃO        1
# 2336104        2011027960     2016/11/23 17:27:54.642000000  2016/11/10 16:55:17.956000000  2016/11/28 10:32:38.000000000  2.016083e+09        ALUNO DE GRADUAÇÃO        1
# 2336105        2014000897     2016/12/02 15:02:53.356000000  2016/11/10 16:55:19.851000000  2016/12/23 13:53:23.000000000  2.014071e+09        ALUNO DE GRADUAÇÃO        1
#                                                                                                                                                                         ..
# 1443383        2010043058     2013/03/21 14:06:09.837000000  2013/03/07 11:17:25.008000000  2013/03/22 11:31:20.000000000  2.010023e+09        ALUNO DE GRADUAÇÃO        1
# 1443387        L147018        2013/03/21 19:43:42.047000000  2013/03/07 11:20:01.159000000  2013/04/04 10:50:22.000000000  2.013053e+09        ALUNO DE GRADUAÇÃO        1
# 1443389        2011018954     2013/03/22 13:18:55.037000000  2013/03/07 11:21:26.480000000  2013/04/08 20:26:07.000000000  2.010046e+09        ALUNO DE GRADUAÇÃO        1
# 1443390        2009056314     2013/03/21 09:28:45.689000000  2013/03/07 11:21:28.899000000  2013/04/05 18:18:00.000000000  2.011015e+09        ALUNO DE GRADUAÇÃO        1
# 10322328       2014070441     2018/01/15 12:26:00.697000000  2017/12/29 18:21:09.060000000  2018/01/31 18:50:25.000000000  2.014063e+09        ALUNO DE GRADUAÇÃO        1
# Length: 968028, dtype: int64

# %%
emprestimos_biblioteca.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 8         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 8  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# 3        2.007211e+08      ALUNO DE GRADUAÇÃO
# 8        2.009046e+09      ALUNO DE GRADUAÇÃO

# %% [markdown]
# ### Importando mais dados

# %%
dados_exemplares = pd.read_parquet('dataset\dados_exemplares.parquet')
dados_exemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# 3                          Biblioteca Central Zila Mamede         REGULAR
# 5                          Biblioteca Central Zila Mamede        ESPECIAL
# ...                                                   ...             ...
# 568580  Biblioteca Setorial do Núcleo de Educação da I...         REGULAR
# 568581                     Biblioteca Central Zila Mamede        ESPECIAL
# 568582                     Biblioteca Central Zila Mamede        ESPECIAL
# 568583                     Biblioteca Central Zila Mamede        ESPECIAL
# 568584                     Biblioteca Central Zila Mamede        ESPECIAL
#
#         localizacao  registro_sistema
# index
# 0               694                 1
# 1               688                 1
# 2               638                 1
# 3               616                 5
# 5               657                15
# ...             ...               ...
# 568580          951            268231
# 568581          997            268233
# 568582          987            268234
# 568583          764            268235
# 568584          962            268236
#
# [546237 rows x 7 columns]

# %% [markdown]
# ### Unindo os DataFrames

# %%
emprestimos_completo = emprestimos_biblioteca.merge(dados_exemplares)
emprestimos_completo
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 2072517        2989018    2009036492                            NaN
# 2072518        2989020    2014062640                            NaN
# 2072519        2989032    2018003324                            NaN
# 2072520        2989049    2006024313                            NaN
# 2072521        2989061    2018031352                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1        2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2        2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3        2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4        2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
# ...                                ...                            ...
# 2072517  2020/03/17 19:49:10.187000000  2020/12/03 08:12:20.000000000
# 2072518  2020/03/17 19:51:15.700000000  2021/01/07 11:16:28.000000000
# 2072519  2020/03/17 20:00:11.416000000  2021/08/30 13:29:44.000000000
# 2072520  2020/03/17 20:47:18.741000000                            NaN
# 2072521  2020/03/17 21:22:22.138000000  2021/07/26 15:05:20.000000000
#
#          matricula_ou_siape    tipo_vinculo_usuario  id_exemplar  \
# 0              2.008023e+09      ALUNO DE GRADUAÇÃO        13259
# 1              2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259
# 2              2.008023e+09      ALUNO DE GRADUAÇÃO        70865
# 3              2.008050e+09      ALUNO DE GRADUAÇÃO        70865
# 4              2.007226e+08      ALUNO DE GRADUAÇÃO        70865
# ...                     ...                     ...          ...
# 2072517        2.015011e+10      ALUNO DE GRADUAÇÃO       274820
# 2072518        2.019004e+10      ALUNO DE GRADUAÇÃO      1157915
# 2072519        2.019102e+10  ALUNO DE PÓS-GRADUAÇÃO      1317173
# 2072520        2.015013e+10      ALUNO DE GRADUAÇÃO       206073
# 2072521        2.020001e+10      ALUNO DE GRADUAÇÃO      1342535
#
#                    colecao                                         biblioteca  \
# 0        Acervo Circulante                     Biblioteca Central Zila Mamede
# 1        Acervo Circulante                     Biblioteca Central Zila Mamede
# 2        Acervo Circulante                     Biblioteca Central Zila Mamede
# 3        Acervo Circulante                     Biblioteca Central Zila Mamede
# 4        Acervo Circulante                     Biblioteca Central Zila Mamede
# ...                    ...                                                ...
# 2072517  Acervo Circulante                     Biblioteca Central Zila Mamede
# 2072518  Acervo Circulante                     Biblioteca Central Zila Mamede
# 2072519  Acervo Circulante  Biblioteca Setorial da Faculdade de Ciências d...
# 2072520  Acervo Circulante                     Biblioteca Central Zila Mamede
# 2072521  Acervo Circulante                     Biblioteca Central Zila Mamede
#
#         status_material  localizacao  registro_sistema
# 0               REGULAR          630              4225
# 1               REGULAR          630              4225
# 2               REGULAR          647             25009
# 3               REGULAR          647             25009
# 4               REGULAR          647             25009
# ...                 ...          ...               ...
# 2072517         REGULAR          676            120845
# 2072518         REGULAR          228            213248
# 2072519         REGULAR          784            255835
# 2072520         REGULAR          663             82178
# 2072521         REGULAR          355            174443
#
# [2072522 rows x 13 columns]

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3        2.008050e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        2.007226e+08      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#    registro_sistema
# 0              4225
# 1              4225
# 2             25009
# 3             25009
# 4             25009

# %% [markdown]
# ### Atribuir a coluna com nomenclatura da CDU

# %%
CDU_lista = []
for CDU in emprestimos_completo['localizacao']:
  if(CDU < 100):
    CDU_lista.append('Generalidades')
  elif(CDU < 200):
    CDU_lista.append('Filosofia e psicologia')
  elif(CDU < 300):
    CDU_lista.append('Religião')
  elif(CDU < 400):
    CDU_lista.append('Ciências sociais')
  elif(CDU < 500):
    CDU_lista.append('Classe vaga')
  elif(CDU < 600):
    CDU_lista.append('Matemática e ciências naturais')
  elif(CDU < 700):
    CDU_lista.append('Ciências aplicadas')
  elif(CDU < 800):
    CDU_lista.append('Belas artes')
  elif(CDU < 900):
    CDU_lista.append('Linguagem')
  else:
    CDU_lista.append('Geografia. Biografia. História.')

emprestimos_completo['CDU_geral'] = CDU_lista

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3        2.008050e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        2.007226e+08      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#    registro_sistema           CDU_geral
# 0              4225  Ciências aplicadas
# 1              4225  Ciências aplicadas
# 2             25009  Ciências aplicadas
# 3             25009  Ciências aplicadas
# 4             25009  Ciências aplicadas

# %% [markdown]
# ### Excluir coluna "registro_sistema"

# %%
emprestimos_completo.drop(columns=['registro_sistema'],inplace=True)

# %% [markdown]
# ### Modificar tipo de dado da matrícula

# %%
emprestimos_completo['matricula_ou_siape'] = emprestimos_completo['matricula_ou_siape'].astype('string')

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1       2009121584.0  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2       2008023265.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3       2008050352.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        200722565.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#             CDU_geral
# 0  Ciências aplicadas
# 1  Ciências aplicadas
# 2  Ciências aplicadas
# 3  Ciências aplicadas
# 4  Ciências aplicadas

# %% [markdown]
# ### Trabalhando com Datas

# %%
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1       2009121584.0  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2       2008023265.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3       2008050352.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        200722565.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#             CDU_geral
# 0  Ciências aplicadas
# 1  Ciências aplicadas
# 2  Ciências aplicadas
# 3  Ciências aplicadas
# 4  Ciências aplicadas

# %% [markdown]
# ### Verificando a relação entre empréstimo e empréstimo de exemplar

# %%
emprestimos_completo['id_emprestimo'].value_counts()
# Out:
# 2010326     3
# 2014596     3
# 10240112    3
# 2422542     3
# 9690168     3
#            ..
# 2767562     1
# 2317930     1
# 2283256     1
# 2262867     1
# 2989061     1
# Name: id_emprestimo, Length: 2068724, dtype: int64

# %%
emprestimos_completo.loc[emprestimos_completo['id_emprestimo']==2560028]
# Out:
# Empty DataFrame
# Columns: [id_emprestimo, codigo_barras, data_renovacao, data_emprestimo, data_devolucao, matricula_ou_siape, tipo_vinculo_usuario, id_exemplar, colecao, biblioteca, status_material, localizacao, CDU_geral]
# Index: []

# %% [markdown]
# Note que o "id_emprestimo" é cada empréstimo realizado que pode ter 1 ou mais exemplares.
#
# Portando cada linha é o empréstimo de cada exemplar.

# %% [markdown]
# ### Quantos empréstimos foram realizados ao total?

# %%
emprestimos = len(emprestimos_completo['id_emprestimo'].drop_duplicates())
emprestimos
# Out:
# 2068724

# %% [markdown]
# ### Quantos exemplares foram emprestados ao total ?

# %%
exemplares = len(emprestimos_completo)
exemplares
# Out:
# 2072522

# %% [markdown]
# ### Quantidade de exemplares emprestados por ano

# %%
emprestimos_data = pd.DataFrame(emprestimos_completo['data_emprestimo'].value_counts()).reset_index()
emprestimos_data.columns = ['data','quantidade']
emprestimos_data['data'] = pd.to_datetime(emprestimos_data['data'])
emprestimos_data
# Out:
#                            data  quantidade
# 0       2017-04-20 21:07:44.036           3
# 1       2014-05-12 09:56:18.787           3
# 2       2015-05-05 20:37:19.551           3
# 3       2018-02-22 10:45:11.523           3
# 4       2014-01-28 14:49:50.505           3
# ...                         ...         ...
# 2068686 2012-04-11 10:12:20.960           1
# 2068687 2010-11-12 11:03:22.117           1
# 2068688 2015-09-15 14:26:08.838           1
# 2068689 2015-08-14 13:41:47.472           1
# 2068690 2020-03-17 21:22:22.138           1
#
# [2068691 rows x 2 columns]

# %%
emprestimos_por_ano = emprestimos_data.groupby(by=emprestimos_data.data.dt.year).sum()
emprestimos_por_ano.index.name = 'ano'
emprestimos_por_ano
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_30488\2983683176.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   emprestimos_por_ano = emprestimos_data.groupby(by=emprestimos_data.data.dt.year).sum()
#       quantidade
# ano
# 2010      161394
# 2011      196390
# 2012      221365
# 2013      234749
# 2014      219189
# 2015      213582
# 2016      215900
# 2017      218462
# 2018      194080
# 2019      171801
# 2020       25610

# %%
sns.set_theme(context='notebook', 
              style='darkgrid', 
              palette='deep', 
              font_scale=1.3, 
              rc={"figure.figsize":(15,8)})

# %%
ax = sns.lineplot(data=emprestimos_por_ano,x='ano',y='quantidade')
ax.set(xlabel=None,ylabel=None)
ax.tick_params(axis='x', rotation=30)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))   

ax.set_title('Quantidade de exemplares emprestados do SISBI por ano'+'\n',size=20,loc='left',weight='bold')

ax=ax

# %% [markdown]
# Pode-ser perceber que desde 2013 os números de exemplares emprestados diminuindo, com uma queda bem grande em 2019.
#
# O ano de 2020 não pode ser avaliado igual, devido ao período da quantidade de dados.
#
# É importante a direção da biblioteca investigar o que está ocorrendo desde 2013 com os procedimentos realizados. Alguns questionamentos importantes que deve-se levar a direção, para que seja aprofundada em outra análise:
#
# O número de alunos da universidade vem diminuindo?
# Como está a pesquisa de satisfação dos usuários da biblioteca?
# O acervo está atualizado?
# Quais são as estratégias de marketing que a biblioteca está realizando?
# O que ocorreu de diferente em 2017 em relação a 2016 e 2015 para que o número tenha se elevado?
# E em 2019?

# %% [markdown]
# ### Quantos foram por cada mês ?

# %%
emprestimos_por_mes = emprestimos_data.groupby(by=emprestimos_data.data.dt.month).sum()
emprestimos_por_mes.index.name = 'mes'
emprestimos_por_mes
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_30488\3499362000.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   emprestimos_por_mes = emprestimos_data.groupby(by=emprestimos_data.data.dt.month).sum()
#      quantidade
# mes
# 1         67514
# 2        210200
# 3        252185
# 4        208725
# 5        202530
# 6        138123
# 7        123790
# 8        232793
# 9        208234
# 10       188410
# 11       164222
# 12        75796

# %% [markdown]
# ### Modificando os números por nomes dos meses

# %%
dicionario_meses = {1:'Jan',2:'Fev',3:'Mar',4:'Abr',
                    5:'Mai',6:'Jun',7:'Jul',8:'Ago',
                    9:'Set',10:'Out',11:'Nov',12:'Dez'}

# %%
emprestimos_por_mes.index = emprestimos_por_mes.index.map(dicionario_meses)

# %%
emprestimos_por_mes
# Out:
#      quantidade
# mes
# Jan       67514
# Fev      210200
# Mar      252185
# Abr      208725
# Mai      202530
# Jun      138123
# Jul      123790
# Ago      232793
# Set      208234
# Out      188410
# Nov      164222
# Dez       75796

# %%
ax = sns.lineplot(data=emprestimos_por_mes,x='mes',y='quantidade')
ax.set(xlabel=None,ylabel=None)
ax.tick_params(axis='x',rotation=30)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))                

ax.set_title("Quantidade de exemplares emprestados do SISBI por mês"+"\n",size=20,loc='left',weight='bold')
ax.text(s='Período de 2010 a 2020',x=-0.5,y=265000,fontsize=18, ha='left',color='gray')

ax=ax

# %% [markdown]
# Pode-se visualizar que os meses com maiores números de exemplares emprestados foram em março e agosto.
#
# Por ser uma biblioteca universitária meses de férias como janeiro, julho e dezembro são os menores números.
#
# O que não é nada de novo, entretanto caso todos os colaboradores saírem de férias durante esse período não conseguiríamos manter todo o funcionamento da biblioteca.
#
# Principalmente com atividades de inventário que podem ocorrer anualmente ou de dois em dois anos e o melhor período seria de dezembro a janeiro.
#
# Então meses como maio, junho, outubro e novembro podem ser uma opção a ser considerada pela direção da biblioteca.
#
# Nota-se também a grande queda no mês de junho. Cabe aqui um alerta para se investigar mais, o que está ocorrendo e desenvolver estratégias e ações de marketing da biblioteca para que se aumente o número de exemplares emprestados.
#
# Como por exemplo: uma ação para que sejam realizados empréstimos de livros para a leitura nas férias de julho.

# %% [markdown]
# ### Qual é a quantidade de empréstimos por hora ao longo do dia ?

# %%
emprestimos_data.data
# Out:
# 0         2017-04-20 21:07:44.036
# 1         2014-05-12 09:56:18.787
# 2         2015-05-05 20:37:19.551
# 3         2018-02-22 10:45:11.523
# 4         2014-01-28 14:49:50.505
#                     ...
# 2068686   2012-04-11 10:12:20.960
# 2068687   2010-11-12 11:03:22.117
# 2068688   2015-09-15 14:26:08.838
# 2068689   2015-08-14 13:41:47.472
# 2068690   2020-03-17 21:22:22.138
# Name: data, Length: 2068691, dtype: datetime64[ns]

# %%
emprestimos_por_hora = emprestimos_data.groupby(by=emprestimos_data.data.dt.hour).sum()
emprestimos_por_hora.index.name = 'horas'
emprestimos_por_hora = emprestimos_por_hora.reset_index()
emprestimos_por_hora
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_30488\2674994335.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   emprestimos_por_hora = emprestimos_data.groupby(by=emprestimos_data.data.dt.hour).sum()
#     horas  quantidade
# 0       0          17
# 1       6          14
# 2       7       18777
# 3       8      103416
# 4       9      131273
# 5      10      185839
# 6      11      180048
# 7      12      148754
# 8      13      126987
# 9      14      150876
# 10     15      166672
# 11     16      210655
# 12     17      185340
# 13     18      182520
# 14     19      102129
# 15     20      127716
# 16     21       51191
# 17     22         247
# 18     23          51

# %%
emprestimos_por_hora = emprestimos_por_hora.sort_values(ascending=True,by='quantidade')

# %%
ax = sns.barplot(data=emprestimos_por_hora,y='quantidade',x='horas',
                 palette='Blues',hue='quantidade',dodge=False)                  #Ordenar pela quantidade de exemplares emprestados
plt.legend([],[], frameon=False)                                                #Excluir a legenda do gráfico

ax.set(xlabel='Horário',ylabel=None)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))           
ax.set_title("Quantidade de exemplares emprestados do SISBI por faixa horária"+"\n",size=20,loc='left',weight='bold')
ax.text(s='Período de 2010 a 2020',x=-0.5,y=225000,fontsize=18, ha='left',color='gray')
ax=ax

# %% [markdown]
# Através do gráfico é possível identificar que os períodos das 10 h e 16 h são os de maior pico no atendimento de empréstimos.
#
# Períodos do começo da manhã (entre 7h e 9) e da noite (entre 19h e 22) podem ser os melhores horários para que se realizem as demais atividades além do atendimento.

# %% [markdown]
# ### Modificando tipo de dado da data de empréstimo do DataFrame

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1       2009121584.0  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2       2008023265.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3       2008050352.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        200722565.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#             CDU_geral
# 0  Ciências aplicadas
# 1  Ciências aplicadas
# 2  Ciências aplicadas
# 3  Ciências aplicadas
# 4  Ciências aplicadas

# %%
emprestimos_completo['data_emprestimo'] = pd.to_datetime(emprestimos_completo['data_emprestimo'])

# %% [markdown]
# ### Verificando valores únicos das variáveis

# %%
emprestimos_completo.tipo_vinculo_usuario.unique()
# Out:
# array(['ALUNO DE GRADUAÇÃO', 'ALUNO DE PÓS-GRADUAÇÃO', 'DOCENTE',
#        'DOCENTE EXTERNO', 'SERVIDOR TÉCNICO-ADMINISTRATIVO',
#        'ALUNO MÉDIO/TÉCNICO', 'USUÁRIO EXTERNO', 'OUTROS'], dtype=object)

# %%
emprestimos_completo.colecao.unique()
# Out:
# array(['Acervo Circulante', 'Folhetos', 'Teses', 'Dissertações',
#        'Monografias', 'Publicações de Autores do RN',
#        'Publicações da UFRN', 'Multimeios', 'Coleção Mossoroense',
#        'Eventos', 'Trabalho Acadêmico', 'Obras de Referência',
#        'Obras Raras', 'Literatura de Cordel', 'Coleção Zila Mamede',
#        'Necessidades Educacionais Específicas'], dtype=object)

# %%
emprestimos_completo.biblioteca.unique()
# Out:
# array(['Biblioteca Central Zila Mamede',
#        'Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#        'Biblioteca Setorial Bertha Cruz Enders - \xadEscola de Saúde da UFRN - ESUFRN',
#        'Biblioteca Setorial do Centro Ciências da Saúde - CCS',
#        'Biblioteca Setorial Prof. Alberto Moreira Campos - \xadDepartamento de Odontologia',
#        'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#        'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#        'Biblioteca Setorial Prof. Horácio Nicolas Solimo - \xad Engenharia Química - EQ - CT',
#        'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#        'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
#        'Biblioteca Setorial do Departamento de Artes - DEART',
#        'Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - \xadCT',
#        'Biblioteca Setorial Árvore do Conhecimento - Instituto do Cérebro - ICe',
#        'Biblioteca Setorial Moacyr de Góes - CE',
#        'Biblioteca Setorial Prof. Leopoldo Nelson - \xadCentro de Biociências - CB',
#        'Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN - Caicó',
#        'Biblioteca Setorial Pe. Jaime Diniz - Escola de Música - EMUFRN',
#        'Biblioteca Setorial Profª. Maria Lúcia da Costa Bezerra - \xadCERES\xad - Caicó',
#        'Biblioteca Setorial Profª. Maria José Mamede Galvão - FELCS - Currais Novos',
#        'Biblioteca Setorial do Núcleo de Educação da Infância - NEI',
#        'Biblioteca Setorial da Faculdade de Ciências da Saúde do Trairi - FACISA - Santa Cruz',
#        'Biblioteca Setorial do Núcleo de Ensino Superior do Agreste - NESA - Nova Cruz'],
#       dtype=object)

# %%
emprestimos_completo.CDU_geral.unique()
# Out:
# array(['Ciências aplicadas', 'Linguagem', 'Ciências sociais',
#        'Geografia. Biografia. História.',
#        'Matemática e ciências naturais', 'Religião', 'Generalidades',
#        'Filosofia e psicologia', 'Belas artes'], dtype=object)

# %% [markdown]
# ## Função

# %%
def tabela_frequencia(variavel):
  '''
  Esta função irá gerar uma tabela de frequência com percentuais de acordo 
  com a variável passada. 

  variavel = variável categórica escolhida de dentro do conjunto de dados 
  emprestimos_completo
  '''

  dataframe = pd.DataFrame(emprestimos_completo[variavel].value_counts())                      
  dataframe.columns = ['quantidade']
  dataframe['percentual'] = round((dataframe.quantidade / dataframe.quantidade.sum())*100,1)

  return dataframe

# %% [markdown]
# ### Quantos foram por tipo de vinculo do usuario ?

# %%
tabela_frequencia('tipo_vinculo_usuario')
# Out:
#                                  quantidade  percentual
# ALUNO DE GRADUAÇÃO                  1612324        77.8
# ALUNO DE PÓS-GRADUAÇÃO               302541        14.6
# DOCENTE                               70981         3.4
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32184         1.6
# ALUNO MÉDIO/TÉCNICO                   28029         1.4
# DOCENTE EXTERNO                       23949         1.2
# USUÁRIO EXTERNO                        2509         0.1
# OUTROS                                    5         0.0

# %% [markdown]
# O maior público da biblioteca são de fato os alunos de graduação com aproxidamente 78% o segundo maior público é o de pós graduação com aproximadamente 15%.
#
# Vale lembrar que esta é apenas uma métrica geral a partir dos exemplares emprestados.
#
# Possilvemente a maior diferença entre os percentuais dos dois anteriores é devido a dois pontos:
#
# Alunos de pós graduação, tem o maior enfoque em artigos científicos que são acessados através de bases de dados bibliográficas.
# A maior quantidade de alunos de graduação em comparação com os da pós na universidade.

# %% [markdown]
# ### Quantos foram por coleção ?

# %%
tabela_frequencia('colecao')
# Out:
#                                        quantidade  percentual
# Acervo Circulante                         2053120        99.1
# Multimeios                                   7954         0.4
# Monografias                                  4021         0.2
# Dissertações                                 2406         0.1
# Obras de Referência                          1954         0.1
# Publicações de Autores do RN                  866         0.0
# Publicações da UFRN                           764         0.0
# Teses                                         714         0.0
# Folhetos                                      271         0.0
# Necessidades Educacionais Específicas         130         0.0
# Trabalho Acadêmico                            115         0.0
# Eventos                                       101         0.0
# Coleção Mossoroense                            44         0.0
# Coleção Zila Mamede                            30         0.0
# Literatura de Cordel                           24         0.0
# Obras Raras                                     8         0.0

# %% [markdown]
# A principal coleção é a própria circulante o que se cria um alerta, pois está com 99% de todos os exemplares empréstados.
#
# Principalmente para as monografias, dissertações e teses que poderiam estar sendo mais consultadas para que haja um crescimento das discussões de pesquisa interna da instituição.
#
# Entretanto é importante verificar se esses documentos não estão disponíveis na coleção online e por este motivo não é emprestada fisicamente.
#
# As coleções: Coleção Mossoroense, Coleção Zila Mamede, Literatura de Cordel, Obras Raras devem ter uma atenção especial em entender a razão que estão com números tão pequenos de frequência.

# %% [markdown]
# ### Quantos foram por biblioteca ?

# %%
tabela_frequencia('biblioteca')
# Out:
#                                                     quantidade  percentual
# Biblioteca Central Zila Mamede                         1426122        68.8
# Biblioteca Setorial do Centro Ciências da Saúde...      118614         5.7
# Biblioteca Setorial da Faculdade de Ciências da...       77609         3.7
# Biblioteca Setorial Prof. Alberto Moreira Campo...       66447         3.2
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       61478         3.0
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       46040         2.2
# Biblioteca Setorial do Centro de Ciências Human...       40744         2.0
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32097         1.5
# Biblioteca Setorial Profª. Maria José Mamede Ga...       29089         1.4
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       27219         1.3
# Biblioteca Setorial Prof. Francisco Gurgel De A...       26923         1.3
# Biblioteca Setorial do Núcleo de Educação da In...       23656         1.1
# Biblioteca Setorial Prof. Ronaldo Xavier de Arr...       22749         1.1
# Biblioteca Setorial Pe. Jaime Diniz - Escola de...       21476         1.0
# Biblioteca Setorial do Departamento de Artes - ...       17099         0.8
# Biblioteca Setorial Prof. Leopoldo Nelson - ­Ce...       12900         0.6
# Biblioteca Setorial do Centro Ciências Sociais ...       10533         0.5
# Biblioteca Setorial Prof. Dr. Marcelo Bezerra d...        5057         0.2
# Biblioteca Setorial Prof. Horácio Nicolas Solim...        4098         0.2
# Biblioteca Setorial Moacyr de Góes - CE                   1036         0.0
# Biblioteca Setorial Árvore do Conhecimento - In...         919         0.0
# Biblioteca Setorial do Núcleo de Ensino Superio...         617         0.0

# %% [markdown]
# Pelo tamanho da biblioteca central era de se esperar que houvesse uma maior predominância dela.
#
# Este ranking é importante para se entender o contexto geral do sistema de bibliotecas, entretanto para que se enriqueça ainda mais essa análise se faz necessário uma avaliação interna de outras métricas, como:
#
# A quantidade esperada de empréstimos.
# Quantidade de empréstimos por usuário cadastrado em cada biblioteca.
# Ações e investimentos realizados em cada uma.

# %% [markdown]
# ### Quantos foram pela CDU geral?

# %%
tabela_frequencia('CDU_geral')
# Out:
#                                  quantidade  percentual
# Ciências aplicadas                  1425473        68.8
# Ciências sociais                     369536        17.8
# Matemática e ciências naturais        68744         3.3
# Generalidades                         62521         3.0
# Religião                              62295         3.0
# Filosofia e psicologia                60563         2.9
# Geografia. Biografia. História.        7989         0.4
# Belas artes                            7911         0.4
# Linguagem                              7490         0.4

# %% [markdown]
# De maneira geral podemos observar que há uma grande diferença entre os temas.
#
# Será importante entender a razão de materiais do tema de Geografia/Biografia/História, Belas artes e Linguagem estão com números tão baixos.
#
# Algumas questões surgem:
#
# O acervo está atualizado?
# O público da biblioteca tem a necessidade destas informações? Se sim, por que não estão usando?
# Quais ações de marketing estão sendo realizadas para esses temas?

# %% [markdown]
# ## Analisando empréstimos com boxplot

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#           data_emprestimo                 data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721  2010/01/05 16:26:12.662000000       2008023265.0
# 1 2010-03-01 12:40:56.212  2010/04/30 14:42:35.366000000       2009121584.0
# 2 2010-01-04 07:44:10.750  2010/01/12 07:34:13.934000000       2008023265.0
# 3 2010-02-11 11:16:30.335  2010/03/04 08:54:32.262000000       2008050352.0
# 4 2010-03-04 13:36:26.599  2010/03/31 18:04:29.669000000        200722565.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#             CDU_geral
# 0  Ciências aplicadas
# 1  Ciências aplicadas
# 2  Ciências aplicadas
# 3  Ciências aplicadas
# 4  Ciências aplicadas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Alunos de graduação

# %%
alunos_graduacao = emprestimos_completo.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
alunos_graduacao.colecao.value_counts()
# Out:
# Acervo Circulante                        1600155
# Multimeios                                  4652
# Monografias                                 3572
# Dissertações                                1152
# Obras de Referência                         1047
# Publicações de Autores do RN                 595
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: colecao, dtype: int64

# %% [markdown]
# ### Criando tabela com a quantidade mensal por ano

# %%
alunos_graduacao_acervo_circulante = alunos_graduacao.query('colecao == "Acervo Circulante"')
alunos_graduacao_acervo_circulante = pd.DataFrame(alunos_graduacao_acervo_circulante)
alunos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_graduacao_acervo_circulante['data_emprestimo'])
alunos_graduacao_acervo_circulante['ano'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_graduacao_acervo_circulante['mes'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.loc[:,['ano','mes']]
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
alunos_graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2012    3       22797
# 1    2015    3       22483
# 2    2013    4       21853
# 3    2017    3       21735
# 4    2016    3       21692
# ..    ...  ...         ...
# 118  2016    1        2670
# 119  2019    1        2276
# 120  2019   12        1980
# 121  2020    1        1781
# 122  2011    1         809
#
# [123 rows x 3 columns]

# %% [markdown]
# ### Função gera_box_plot

# %%
def gera_box_plot(dataset,x,y,titulo,subtitulo):
  '''
  Esta função irá gerar um gráfico de boxplot.

  Dataset = conjunto de dados do gráfico
  x = valor do eixo x do gráfico
  y = valor do eixo y do gráfico
  título = título do gráfico
  subtitulo = subtitulo do texto
  '''

  sns.set_theme(style="darkgrid", palette='Blues',font_scale=1.3)                    
  plt.figure(figsize=(16,10))                                                           

  ax = sns.boxplot(y= y, x= x, data= dataset,color='#4171EF')                                           
  ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))                


  plt.ylim(0,max(dataset[y])*1.1)                                               #Definir o limite do eixo y
  plt.xlabel(None)                                                                     
  plt.ylabel(None)                                                                    

  ax.set_title(titulo+"\n",size=20,loc='left',weight='bold')
  ax.text(s=subtitulo,x=-0.5,y=max(dataset[y])*1.11,fontsize=18, ha='left',color='gray')

# %% [markdown]
# ### Distribuição dos empréstimos mensais realizados pelos alunos de graduação na coleção do acervo circulante

# %%
gera_box_plot(alunos_graduacao_acervo_circulante,'ano','quantidade','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de graduação no acervo circulante')

# %% [markdown]
# É importante ressaltar que esse recorte, reflete grande parte da estrutura geral do conjunto de dados, pois são os tipos de usuários com maior frequência (alunos de graduação) e da coleção mais utilizada por eles (acervo circulante).
#
# Com o boxplot é possível observar a oscilação da quantidade de empréstimos realizados mensalmente durante cada ano.
#
# Além da análise geral realizada (declínio a partir de 2013, forte baixa em 2019), chama atenção os anos de 2014 e 2017. Que se excluíssemos os outliers (possivelmente meses de janeiro e dezembro) teríamos anos com uma quantidade constante de empréstimos mensais.
#
# Mas se diferenciam principalmente porque em 2014 houve um declínio e em 2017 houve um aumento, em relação aos anos anteriores. Seria interessante entender com a direção das bibliotecas o que ocorreu nessas datas para que pudéssemos ter um contexto melhor da realidade do negócio.

# %% [markdown]
# ### Aluno de pós graduação

# %%
alunos_pos_graduacao = emprestimos_completo.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"')
alunos_pos_graduacao.colecao.value_counts()
# Out:
# Acervo Circulante                        299201
# Dissertações                                934
# Obras de Referência                         700
# Multimeios                                  559
# Teses                                       367
# Monografias                                 278
# Publicações de Autores do RN                204
# Publicações da UFRN                         121
# Folhetos                                     60
# Necessidades Educacionais Específicas        30
# Eventos                                      26
# Coleção Mossoroense                          23
# Trabalho Acadêmico                           23
# Coleção Zila Mamede                          11
# Literatura de Cordel                          4
# Name: colecao, dtype: int64

# %% [markdown]
# ### Criando tabela com a quantidade mensal por ano

# %%
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao.query('colecao == "Acervo Circulante"')
alunos_pos_graduacao_acervo_circulante = pd.DataFrame(alunos_pos_graduacao_acervo_circulante)
alunos_pos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_pos_graduacao_acervo_circulante['data_emprestimo'])
alunos_pos_graduacao_acervo_circulante['ano'] = alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_pos_graduacao_acervo_circulante['mes'] = alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao_acervo_circulante.loc[:,['ano','mes']]
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
alunos_pos_graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2015    3        3927
# 1    2017    8        3837
# 2    2017    3        3722
# 3    2016    3        3711
# 4    2016    8        3662
# ..    ...  ...         ...
# 119  2020    1        1143
# 120  2010    1        1105
# 121  2019   12        1069
# 122  2011    1         465
# 123  2020    6           2
#
# [124 rows x 3 columns]

# %% [markdown]
# ### Distribuição dos empréstimos mensais realizados pelos alunos de pós graduação na coleção do acervo circulante

# %%
gera_box_plot(alunos_pos_graduacao_acervo_circulante,'ano','quantidade','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de pós-graduação no acervo circulante')

# %% [markdown]
# Já os alunos de pós graduação tiveram um aspecto diferente em relação ao declínio a partir de 2013:
#
# A linha mediana foi diminuindo devagar até 2018. Entretanto valores máximos foram superiores, apenas caindo de fato em 2019.
# Nos dois gráficos podemos observar um grande aumento entre 2010 e 2013, o que nos leva a pensar em quais procedimentos estavam sendo realizados neste período para que houvesse esse crescimento.
#
# Nos dois recortes visualizamos que a partir de 2018 tivemos um forte declínio e é um alerta para que a direção possa entender o que está ocorrendo.

# %% [markdown]
# ## Novos dados, novas análises

# %% [markdown]
# ### Arquivo excel

# %%
cadastro_usuarios_antes_2010 = pd.read_excel('dataset\matricula_alunos.xlsx',
                                        sheet_name='Até 2010',skiprows=1)
cadastro_usuarios_depois_2010 = pd.read_excel('dataset\matricula_alunos.xlsx',
                                        sheet_name='Após 2010',skiprows=1)

# %%
cadastro_usuarios_antes_2010
# Out:
#       Número da matrícula     Tipo de vinculo  \
# 0            1.900017e+08  ALUNO DE GRADUAÇÃO
# 1            1.990145e+08  ALUNO DE GRADUAÇÃO
# 2            1.997357e+08  ALUNO DE GRADUAÇÃO
# 3            1.998124e+08  ALUNO DE GRADUAÇÃO
# 4            1.998237e+08  ALUNO DE GRADUAÇÃO
# ...                   ...                 ...
# 7721         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7722         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7723         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7724         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7725         2.009075e+09  ALUNO DE GRADUAÇÃO
#
#                                       Curso
# 0                                MATEMÁTICA
# 1                       CIÊNCIAS BIOLÓGICAS
# 2                                MATEMÁTICA
# 3                                    LETRAS
# 4                                  ECOLOGIA
# ...                                     ...
# 7721                        BIBLIOTECONOMIA
# 7722  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# 7723                          ADMINISTRAÇÃO
# 7724                                 MÚSICA
# 7725                                DIREITO
#
# [7726 rows x 3 columns]

# %%
cadastro_usuarios_antes_2010.columns = ['matricula_ou_siape','tipo_vinculo_usuario','curso']

# %%
cadastro_usuarios_depois_2010
# Out:
#         Matricula      Tipo de vinculo                    Cursos
# 0     2.010000e+09  ALUNO DE GRADUAÇÃO                   DIREITO
# 1     2.010000e+09  ALUNO DE GRADUAÇÃO                 AGRONOMIA
# 2     2.010001e+09  ALUNO DE GRADUAÇÃO        ENGENHARIA QUÍMICA
# 3     2.010003e+09  ALUNO DE GRADUAÇÃO      ENGENHARIA AMBIENTAL
# 4     2.010003e+09  ALUNO DE GRADUAÇÃO                 GEOGRAFIA
# ...            ...                 ...                       ...
# 2269  2.015012e+10  ALUNO DE GRADUAÇÃO                    LETRAS
# 2270  2.015075e+09  ALUNO DE GRADUAÇÃO                     DANÇA
# 2271  2.016000e+10  ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 2272  2.017009e+10  ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 2273  2.018009e+10  ALUNO DE GRADUAÇÃO                     DANÇA
#
# [2274 rows x 3 columns]

# %%
cadastro_usuarios_depois_2010.columns= ['matricula_ou_siape','tipo_vinculo_usuario','curso']

# %%
cadastro_usuarios_excel = pd.concat([cadastro_usuarios_antes_2010,cadastro_usuarios_depois_2010],ignore_index=True)
cadastro_usuarios_excel.matricula_ou_siape = cadastro_usuarios_excel.matricula_ou_siape.astype('string')
cadastro_usuarios_excel
# Out:
#      matricula_ou_siape tipo_vinculo_usuario                     curso
# 0           190001688.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 1           199014489.0   ALUNO DE GRADUAÇÃO       CIÊNCIAS BIOLÓGICAS
# 2           199735674.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 3           199812431.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 4           199823670.0   ALUNO DE GRADUAÇÃO                  ECOLOGIA
# ...                 ...                  ...                       ...
# 9995      20150116770.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 9996       2015074523.0   ALUNO DE GRADUAÇÃO                     DANÇA
# 9997      20160002745.0   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 9998      20170086533.0   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 9999      20180090351.0   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [10000 rows x 3 columns]

# %% [markdown]
# ### Arquivo JSON

# %%
cadastro_usuarios_json = pd.read_json('dataset\cadastro_alunos.json')
cadastro_usuarios_json
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %%
cadastro_usuarios_graduacao_json = pd.read_json(cadastro_usuarios_json.registros[0])

# %%
cadastro_usuarios_graduacao_json
# Out:
#        matricula_ou_siape tipo_vinculo_usuario                   curso
# 0              2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1               200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2               200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3               200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4               200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO
# ...                   ...                  ...                     ...
# 62797         20200012706   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62798         20200039601   ALUNO DE GRADUAÇÃO    ENGENHARIA FLORESTAL
# 62799         20200132517   ALUNO DE GRADUAÇÃO               AGRONOMIA
# 62800         20200009344   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62801         20200090284   ALUNO DE GRADUAÇÃO                 DIREITO
#
# [62802 rows x 3 columns]

# %%
cadastro_usuarios_graduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  int64
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Modificando tipo de dado da matricula

# %%
cadastro_usuarios_graduacao_json.matricula_ou_siape = cadastro_usuarios_graduacao_json.matricula_ou_siape.astype('float')
cadastro_usuarios_graduacao_json.matricula_ou_siape = cadastro_usuarios_graduacao_json.matricula_ou_siape.astype('string')

# %%
cadastro_usuarios_graduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  string
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: object(2), string(1)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Concatenando arquivos Excel e JSON

# %%
cadastro_usuarios_cursos = pd.concat([cadastro_usuarios_excel,cadastro_usuarios_graduacao_json],ignore_index=True)
cadastro_usuarios_cursos
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                 curso
# 0            190001688.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 1            199014489.0   ALUNO DE GRADUAÇÃO   CIÊNCIAS BIOLÓGICAS
# 2            199735674.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 3            199812431.0   ALUNO DE GRADUAÇÃO                LETRAS
# 4            199823670.0   ALUNO DE GRADUAÇÃO              ECOLOGIA
# ...                  ...                  ...                   ...
# 72797      20200012706.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72798      20200039601.0   ALUNO DE GRADUAÇÃO  ENGENHARIA FLORESTAL
# 72799      20200132517.0   ALUNO DE GRADUAÇÃO             AGRONOMIA
# 72800      20200009344.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72801      20200090284.0   ALUNO DE GRADUAÇÃO               DIREITO
#
# [72802 rows x 3 columns]

# %% [markdown]
# ## Empréstimos dos alunos de graduação de 2015 em diante

# %%
matricula_data_de_emprestimo = emprestimos_completo.query("tipo_vinculo_usuario == 'ALUNO DE GRADUAÇÃO'")
matricula_data_de_emprestimo = matricula_data_de_emprestimo.loc[:,['matricula_ou_siape','data_emprestimo']]
matricula_data_de_emprestimo = matricula_data_de_emprestimo.query('data_emprestimo > 2015')
matricula_data_de_emprestimo = matricula_data_de_emprestimo.reset_index(drop=True)
matricula_data_de_emprestimo
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2014083920.0 2015-02-03 14:56:17.005
# 1            2014083949.0 2015-03-06 13:16:57.907
# 2            2014083920.0 2015-04-06 16:58:10.691
# 3            2014083920.0 2015-05-27 17:39:48.592
# 4            2014084089.0 2015-07-28 17:46:49.875
# ...                   ...                     ...
# 788099      20160144295.0 2020-03-17 18:33:29.752
# 788100      20150109837.0 2020-03-17 19:49:10.187
# 788101      20190035012.0 2020-03-17 19:51:15.700
# 788102      20150129867.0 2020-03-17 20:47:18.741
# 788103      20200005327.0 2020-03-17 21:22:22.138
#
# [788104 rows x 2 columns]

# %% [markdown]
# ### Excluindo valores nulos de matricula

# %%
matricula_data_de_emprestimo.isna().sum()
# Out:
# matricula_ou_siape    94
# data_emprestimo        0
# dtype: int64

# %%
matricula_data_de_emprestimo = matricula_data_de_emprestimo.dropna()

# %% [markdown]
# ### Filtrar cursos selecionados

# %%
cadastro_usuarios_cursos_selecionados = cadastro_usuarios_cursos.query("curso == ['BIBLIOTECONOMIA','CIÊNCIAS SOCIAIS','COMUNICAÇÃO SOCIAL','DIREITO','FILOSOFIA','PEDAGOGIA']")
cadastro_usuarios_cursos_selecionados
# Out:
#       matricula_ou_siape tipo_vinculo_usuario             curso
# 8            200031011.0   ALUNO DE GRADUAÇÃO           DIREITO
# 9            200045080.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 15           200115053.0   ALUNO DE GRADUAÇÃO  CIÊNCIAS SOCIAIS
# 18           200123382.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 19           200123730.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# ...                  ...                  ...               ...
# 72789      20200097481.0   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72796      20200107087.0   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72797      20200012706.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72800      20200009344.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72801      20200090284.0   ALUNO DE GRADUAÇÃO           DIREITO
#
# [18833 rows x 3 columns]

# %% [markdown]
# ### Unir DataFrames de cadastro de usuários com o de empréstimos

# %%
cadastro_usuarios_cursos_selecionados = matricula_data_de_emprestimo.merge(cadastro_usuarios_cursos_selecionados)
cadastro_usuarios_cursos_selecionados
# Out:
#        matricula_ou_siape         data_emprestimo tipo_vinculo_usuario  \
# 0           20180154181.0 2018-09-18 20:07:53.876   ALUNO DE GRADUAÇÃO
# 1           20180154181.0 2020-03-04 16:17:32.383   ALUNO DE GRADUAÇÃO
# 2           20180154181.0 2018-12-07 19:00:16.733   ALUNO DE GRADUAÇÃO
# 3           20180154181.0 2018-08-21 19:39:07.928   ALUNO DE GRADUAÇÃO
# 4           20180154181.0 2018-09-28 18:38:58.259   ALUNO DE GRADUAÇÃO
# ...                   ...                     ...                  ...
# 212833      20200023906.0 2020-03-13 08:45:15.420   ALUNO DE GRADUAÇÃO
# 212834      20190121101.0 2020-03-13 09:08:44.544   ALUNO DE GRADUAÇÃO
# 212835      20200144278.0 2020-03-13 09:16:50.082   ALUNO DE GRADUAÇÃO
# 212836      20190067212.0 2020-03-13 21:41:01.524   ALUNO DE GRADUAÇÃO
# 212837      20190067212.0 2020-03-13 21:41:01.560   ALUNO DE GRADUAÇÃO
#
#                    curso
# 0        BIBLIOTECONOMIA
# 1        BIBLIOTECONOMIA
# 2        BIBLIOTECONOMIA
# 3        BIBLIOTECONOMIA
# 4        BIBLIOTECONOMIA
# ...                  ...
# 212833  CIÊNCIAS SOCIAIS
# 212834   BIBLIOTECONOMIA
# 212835         PEDAGOGIA
# 212836  CIÊNCIAS SOCIAIS
# 212837  CIÊNCIAS SOCIAIS
#
# [212838 rows x 4 columns]

# %%
cadastro_usuarios_cursos_selecionados.data_emprestimo = cadastro_usuarios_cursos_selecionados.data_emprestimo.dt.year

# %%
emprestimos_cursos_selecionados = cadastro_usuarios_cursos_selecionados.iloc[:,[1,3]].value_counts().reset_index()
emprestimos_cursos_selecionados.columns = ['ANO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimos_cursos_selecionados
# Out:
#      ANO               CURSO  QUANTIDADE_EMPRESTIMOS
# 0   2017  COMUNICAÇÃO SOCIAL                    8253
# 1   2016  COMUNICAÇÃO SOCIAL                    7973
# 2   2017             DIREITO                    7885
# 3   2015     BIBLIOTECONOMIA                    7784
# 4   2015             DIREITO                    7665
# 5   2016           FILOSOFIA                    7576
# 6   2015    CIÊNCIAS SOCIAIS                    7489
# 7   2017           PEDAGOGIA                    7434
# 8   2017           FILOSOFIA                    7389
# 9   2016             DIREITO                    7363
# 10  2017     BIBLIOTECONOMIA                    7307
# 11  2015           PEDAGOGIA                    7189
# 12  2016           PEDAGOGIA                    7153
# 13  2015  COMUNICAÇÃO SOCIAL                    7147
# 14  2016     BIBLIOTECONOMIA                    7044
# 15  2018             DIREITO                    7027
# 16  2016    CIÊNCIAS SOCIAIS                    6978
# 17  2018  COMUNICAÇÃO SOCIAL                    6953
# 18  2015           FILOSOFIA                    6950
# 19  2017    CIÊNCIAS SOCIAIS                    6918
# 20  2018           PEDAGOGIA                    6518
# 21  2018     BIBLIOTECONOMIA                    6378
# 22  2018           FILOSOFIA                    6296
# 23  2018    CIÊNCIAS SOCIAIS                    6181
# 24  2019     BIBLIOTECONOMIA                    5889
# 25  2019  COMUNICAÇÃO SOCIAL                    5885
# 26  2019           PEDAGOGIA                    5869
# 27  2019             DIREITO                    5861
# 28  2019    CIÊNCIAS SOCIAIS                    5788
# 29  2019           FILOSOFIA                    5572
# 30  2020             DIREITO                     905
# 31  2020     BIBLIOTECONOMIA                     900
# 32  2020           PEDAGOGIA                     866
# 33  2020           FILOSOFIA                     832
# 34  2020    CIÊNCIAS SOCIAIS                     825
# 35  2020  COMUNICAÇÃO SOCIAL                     796

# %% [markdown]
# ### Tabela Pivotada

# %%
emprestimos_tipo_usuario_curso_pivot = emprestimos_cursos_selecionados.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS',
        fill_value = '-',
        aggfunc= sum,
        margins = True,
        margins_name = 'TOTAL',
)
emprestimos_tipo_usuario_curso_pivot
# Out:
# ANO                  2015   2016   2017   2018   2019  2020   TOTAL
# CURSO
# BIBLIOTECONOMIA      7784   7044   7307   6378   5889   900   35302
# CIÊNCIAS SOCIAIS     7489   6978   6918   6181   5788   825   34179
# COMUNICAÇÃO SOCIAL   7147   7973   8253   6953   5885   796   37007
# DIREITO              7665   7363   7885   7027   5861   905   36706
# FILOSOFIA            6950   7576   7389   6296   5572   832   34615
# PEDAGOGIA            7189   7153   7434   6518   5869   866   35029
# TOTAL               44224  44087  45186  39353  34864  5124  212838

# %% [markdown]
# ## Apresentando resultados em HTML

# %%
import pandas as pd

# %% [markdown]
# ### Importando cadastro de usuários apenas de pós graduação

# %% [markdown]
# ### Arquivo excel

# %%
cadastro_usuarios_antes_2010 = pd.read_excel('dataset\matricula_alunos.xlsx',
                                        sheet_name='Até 2010',skiprows=1)
cadastro_usuarios_depois_2010 = pd.read_excel('dataset\matricula_alunos.xlsx',
                                        sheet_name='Após 2010',skiprows=1)

# %%
cadastro_usuarios_antes_2010
# Out:
#       Número da matrícula     Tipo de vinculo  \
# 0            1.900017e+08  ALUNO DE GRADUAÇÃO
# 1            1.990145e+08  ALUNO DE GRADUAÇÃO
# 2            1.997357e+08  ALUNO DE GRADUAÇÃO
# 3            1.998124e+08  ALUNO DE GRADUAÇÃO
# 4            1.998237e+08  ALUNO DE GRADUAÇÃO
# ...                   ...                 ...
# 7721         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7722         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7723         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7724         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7725         2.009075e+09  ALUNO DE GRADUAÇÃO
#
#                                       Curso
# 0                                MATEMÁTICA
# 1                       CIÊNCIAS BIOLÓGICAS
# 2                                MATEMÁTICA
# 3                                    LETRAS
# 4                                  ECOLOGIA
# ...                                     ...
# 7721                        BIBLIOTECONOMIA
# 7722  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# 7723                          ADMINISTRAÇÃO
# 7724                                 MÚSICA
# 7725                                DIREITO
#
# [7726 rows x 3 columns]

# %%
cadastro_usuarios_antes_2010.columns = ['matricula_ou_siape','tipo_vinculo_usuario','curso']

# %%
cadastro_usuarios_depois_2010
# Out:
#         Matricula      Tipo de vinculo                    Cursos
# 0     2.010000e+09  ALUNO DE GRADUAÇÃO                   DIREITO
# 1     2.010000e+09  ALUNO DE GRADUAÇÃO                 AGRONOMIA
# 2     2.010001e+09  ALUNO DE GRADUAÇÃO        ENGENHARIA QUÍMICA
# 3     2.010003e+09  ALUNO DE GRADUAÇÃO      ENGENHARIA AMBIENTAL
# 4     2.010003e+09  ALUNO DE GRADUAÇÃO                 GEOGRAFIA
# ...            ...                 ...                       ...
# 2269  2.015012e+10  ALUNO DE GRADUAÇÃO                    LETRAS
# 2270  2.015075e+09  ALUNO DE GRADUAÇÃO                     DANÇA
# 2271  2.016000e+10  ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 2272  2.017009e+10  ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 2273  2.018009e+10  ALUNO DE GRADUAÇÃO                     DANÇA
#
# [2274 rows x 3 columns]

# %%
cadastro_usuarios_depois_2010.columns= ['matricula_ou_siape','tipo_vinculo_usuario','curso']

# %%
cadastro_usuarios_excel = pd.concat([cadastro_usuarios_antes_2010,cadastro_usuarios_depois_2010],ignore_index=True)
cadastro_usuarios_excel.matricula_ou_siape = cadastro_usuarios_excel.matricula_ou_siape.astype('string')
cadastro_usuarios_excel
# Out:
#      matricula_ou_siape tipo_vinculo_usuario                     curso
# 0           190001688.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 1           199014489.0   ALUNO DE GRADUAÇÃO       CIÊNCIAS BIOLÓGICAS
# 2           199735674.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 3           199812431.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 4           199823670.0   ALUNO DE GRADUAÇÃO                  ECOLOGIA
# ...                 ...                  ...                       ...
# 9995      20150116770.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 9996       2015074523.0   ALUNO DE GRADUAÇÃO                     DANÇA
# 9997      20160002745.0   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 9998      20170086533.0   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 9999      20180090351.0   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [10000 rows x 3 columns]

# %% [markdown]
# ### Arquivo JSON

# %%
cadastro_usuarios_json = pd.read_json('dataset\cadastro_alunos.json')
cadastro_usuarios_json
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %% [markdown]
# ### Criando filtro usuarios somente de pós-graduação

# %%
cadastro_usuarios_posgraduacao_json = pd.read_json(cadastro_usuarios_json.registros[1])

# %%
cadastro_usuarios_posgraduacao_json
# Out:
#        matricula_ou_siape    tipo_vinculo_usuario  \
# 0              2008112114  ALUNO DE PÓS-GRADUAÇÃO
# 1              2008106583  ALUNO DE PÓS-GRADUAÇÃO
# 2              2011101417  ALUNO DE PÓS-GRADUAÇÃO
# 3              2011113122  ALUNO DE PÓS-GRADUAÇÃO
# 4              2010110903  ALUNO DE PÓS-GRADUAÇÃO
# ...                   ...                     ...
# 19435         20201013501  ALUNO DE PÓS-GRADUAÇÃO
# 19436         20201014062  ALUNO DE PÓS-GRADUAÇÃO
# 19437         20201017690  ALUNO DE PÓS-GRADUAÇÃO
# 19438         20201014465  ALUNO DE PÓS-GRADUAÇÃO
# 19439         20201014993  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                      CIÊNCIAS ODONTOLÓGICAS
# 1                      ENGENHARIA DE SOFTWARE
# 2                     ARQUITETURA E URBANISMO
# 3                                   FILOSOFIA
# 4                               ARTES CÊNICAS
# ...                                       ...
# 19435  GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO
# 19436          CIÊNCIA, TECNOLOGIA E INOVAÇÃO
# 19437                       CIÊNCIAS DA SAÚDE
# 19438                                  DESIGN
# 19439                                  DESIGN
#
# [19440 rows x 3 columns]

# %%
cadastro_usuarios_posgraduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19440 entries, 0 to 19439
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    19440 non-null  int64
#  1   tipo_vinculo_usuario  19440 non-null  object
#  2   curso                 19440 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 455.8+ KB

# %% [markdown]
# ### Modificando tipo de dado da matricula

# %%
cadastro_usuarios_posgraduacao_json.matricula_ou_siape = cadastro_usuarios_posgraduacao_json.matricula_ou_siape.astype('float')
cadastro_usuarios_posgraduacao_json.matricula_ou_siape = cadastro_usuarios_posgraduacao_json.matricula_ou_siape.astype('string')

# %%
cadastro_usuarios_posgraduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19440 entries, 0 to 19439
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    19440 non-null  string
#  1   tipo_vinculo_usuario  19440 non-null  object
#  2   curso                 19440 non-null  object
# dtypes: object(2), string(1)
# memory usage: 455.8+ KB

# %% [markdown]
# ### Concatenando arquivos Excel e JSON

# %%
cadastro_usuarios_cursos = pd.concat([cadastro_usuarios_excel,cadastro_usuarios_posgraduacao_json],ignore_index=True)
cadastro_usuarios_cursos
# Out:
#       matricula_ou_siape    tipo_vinculo_usuario  \
# 0            190001688.0      ALUNO DE GRADUAÇÃO
# 1            199014489.0      ALUNO DE GRADUAÇÃO
# 2            199735674.0      ALUNO DE GRADUAÇÃO
# 3            199812431.0      ALUNO DE GRADUAÇÃO
# 4            199823670.0      ALUNO DE GRADUAÇÃO
# ...                  ...                     ...
# 29435      20201013501.0  ALUNO DE PÓS-GRADUAÇÃO
# 29436      20201014062.0  ALUNO DE PÓS-GRADUAÇÃO
# 29437      20201017690.0  ALUNO DE PÓS-GRADUAÇÃO
# 29438      20201014465.0  ALUNO DE PÓS-GRADUAÇÃO
# 29439      20201014993.0  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                                  MATEMÁTICA
# 1                         CIÊNCIAS BIOLÓGICAS
# 2                                  MATEMÁTICA
# 3                                      LETRAS
# 4                                    ECOLOGIA
# ...                                       ...
# 29435  GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO
# 29436          CIÊNCIA, TECNOLOGIA E INOVAÇÃO
# 29437                       CIÊNCIAS DA SAÚDE
# 29438                                  DESIGN
# 29439                                  DESIGN
#
# [29440 rows x 3 columns]

# %%
cadastro_usuarios_cursos_pos_graduacao = cadastro_usuarios_posgraduacao_json.query("tipo_vinculo_usuario == 'ALUNO DE PÓS-GRADUAÇÃO'")
cadastro_usuarios_cursos_pos_graduacao
# Out:
#       matricula_ou_siape    tipo_vinculo_usuario  \
# 0           2008112114.0  ALUNO DE PÓS-GRADUAÇÃO
# 1           2008106583.0  ALUNO DE PÓS-GRADUAÇÃO
# 2           2011101417.0  ALUNO DE PÓS-GRADUAÇÃO
# 3           2011113122.0  ALUNO DE PÓS-GRADUAÇÃO
# 4           2010110903.0  ALUNO DE PÓS-GRADUAÇÃO
# ...                  ...                     ...
# 19435      20201013501.0  ALUNO DE PÓS-GRADUAÇÃO
# 19436      20201014062.0  ALUNO DE PÓS-GRADUAÇÃO
# 19437      20201017690.0  ALUNO DE PÓS-GRADUAÇÃO
# 19438      20201014465.0  ALUNO DE PÓS-GRADUAÇÃO
# 19439      20201014993.0  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                      CIÊNCIAS ODONTOLÓGICAS
# 1                      ENGENHARIA DE SOFTWARE
# 2                     ARQUITETURA E URBANISMO
# 3                                   FILOSOFIA
# 4                               ARTES CÊNICAS
# ...                                       ...
# 19435  GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO
# 19436          CIÊNCIA, TECNOLOGIA E INOVAÇÃO
# 19437                       CIÊNCIAS DA SAÚDE
# 19438                                  DESIGN
# 19439                                  DESIGN
#
# [19440 rows x 3 columns]

# %% [markdown]
# ### Filtrando empréstimos desde de 2017

# %%
matricula_data_de_emprestimo_pos_graduacao = emprestimos_completo.loc[:,['matricula_ou_siape','data_emprestimo']]
matricula_data_de_emprestimo_pos_graduacao = matricula_data_de_emprestimo_pos_graduacao.query('data_emprestimo > 2017')
matricula_data_de_emprestimo_pos_graduacao = matricula_data_de_emprestimo_pos_graduacao.reset_index(drop=True)
matricula_data_de_emprestimo_pos_graduacao
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2013043297.0 2017-02-16 16:39:45.480
# 1           20171029059.0 2017-03-28 09:04:09.781
# 2            2013043297.0 2017-04-24 20:01:50.300
# 3            2016008166.0 2017-06-19 19:59:41.522
# 4           20170083498.0 2017-07-24 08:40:48.277
# ...                   ...                     ...
# 609948      20150109837.0 2020-03-17 19:49:10.187
# 609949      20190035012.0 2020-03-17 19:51:15.700
# 609950      20191021693.0 2020-03-17 20:00:11.416
# 609951      20150129867.0 2020-03-17 20:47:18.741
# 609952      20200005327.0 2020-03-17 21:22:22.138
#
# [609953 rows x 2 columns]

# %% [markdown]
# ### Unindo DataFrames de cadastro de usuários e de empréstimos

# %%
emprestimos_pos_graduacao_desde_2017 = matricula_data_de_emprestimo_pos_graduacao.merge(cadastro_usuarios_cursos_pos_graduacao)
emprestimos_pos_graduacao_desde_2017
# Out:
#       matricula_ou_siape         data_emprestimo    tipo_vinculo_usuario  \
# 0          20171029059.0 2017-03-28 09:04:09.781  ALUNO DE PÓS-GRADUAÇÃO
# 1          20171029059.0 2017-05-09 15:07:27.165  ALUNO DE PÓS-GRADUAÇÃO
# 2          20171029059.0 2017-06-12 08:37:05.048  ALUNO DE PÓS-GRADUAÇÃO
# 3          20171029059.0 2018-03-19 10:10:03.552  ALUNO DE PÓS-GRADUAÇÃO
# 4          20171029059.0 2018-08-24 19:36:53.956  ALUNO DE PÓS-GRADUAÇÃO
# ...                  ...                     ...                     ...
# 92057      20201006310.0 2020-03-12 13:45:36.288  ALUNO DE PÓS-GRADUAÇÃO
# 92058      20201006310.0 2020-03-12 13:45:36.326  ALUNO DE PÓS-GRADUAÇÃO
# 92059      20191006490.0 2020-03-12 16:10:31.448  ALUNO DE PÓS-GRADUAÇÃO
# 92060      20201011795.0 2020-03-16 12:24:44.550  ALUNO DE PÓS-GRADUAÇÃO
# 92061      20201004360.0 2020-03-17 12:34:19.327  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                                   FILOSOFIA
# 1                                   FILOSOFIA
# 2                                   FILOSOFIA
# 3                                   FILOSOFIA
# 4                                   FILOSOFIA
# ...                                       ...
# 92057                 ARQUITETURA E URBANISMO
# 92058                 ARQUITETURA E URBANISMO
# 92059                 ARQUITETURA E URBANISMO
# 92060  GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO
# 92061                  CIÊNCIAS ODONTOLÓGICAS
#
# [92062 rows x 4 columns]

# %% [markdown]
# ### Modificando tipo de data

# %%
emprestimos_pos_graduacao_desde_2017.data_emprestimo = emprestimos_pos_graduacao_desde_2017.data_emprestimo.dt.year

# %% [markdown]
# ### Contando valores de empréstimos

# %%
emprestimos_pos_graduacao_desde_2017 = emprestimos_pos_graduacao_desde_2017.iloc[:,[1,3]].value_counts().reset_index()
emprestimos_pos_graduacao_desde_2017.columns = ['ANO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimos_pos_graduacao_desde_2017.head()
# Out:
#     ANO                           CURSO  QUANTIDADE_EMPRESTIMOS
# 0  2018          CIÊNCIAS ODONTOLÓGICAS                    2540
# 1  2017                   ADMINISTRAÇÃO                    2538
# 2  2017          ENGENHARIA DE SOFTWARE                    2477
# 3  2017               CIÊNCIAS DA SAÚDE                    2434
# 4  2017  CIÊNCIA, TECNOLOGIA E INOVAÇÃO                    2415

# %% [markdown]
# ### Pivotando tabela

# %%
emprestimos_pos_graduacao_e_curso_pivot = emprestimos_pos_graduacao_desde_2017.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS'
)
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                     2017  2018  2019  2020
# CURSO
# ADMINISTRAÇÃO                           2538  2316  1692   269
# ARQUITETURA E URBANISMO                 2209  1917  1818   257
# ARTES CÊNICAS                           2115  2082  1812   229
# BIOINFORMÁTICA                          2190  1914  1825   263
# BIOQUÍMICA                              2294  1944  2057   272
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316  2110  2008   328
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415  2365  2026   303
# CIÊNCIAS DA SAÚDE                       2434  1986  1825   234
# CIÊNCIAS ODONTOLÓGICAS                  2414  2540  2134   352
# DESIGN                                  2272  1838  1841   254
# ENGENHARIA CIVIL                        2399  2089  1989   254
# ENGENHARIA DE SOFTWARE                  2477  2222  1887   264
# FILOSOFIA                               2170  2048  1773   302
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO  2266  1891  1771   252

# %% [markdown]
# ### Importando dados da previsão

# %%
previsao_2022 = pd.read_table('dataset\previsao')

# %% [markdown]
# ### Tratando dados da previsão

# %%
previsao_2022 = previsao_2022['curso previsao_2022'].str.split(' ',expand=True)
previsao_2022
# Out:
#                                          0     1
# 0                            administracao  1905
# 1                  arquitetura_e_urbanismo  1896
# 2                            artes_cenicas  1920
# 3                           bioinformatica  2302
# 4                               bioquimica  2090
# 5        ciencia_e_engenharia_de_materiais  2010
# 6            ciencia_tecnologia_e_inovacao  1960
# 7                        ciencias_da_saude  1730
# 8                   ciencias_odontologicas  2405
# 9                                   design  1900
# 10                        engenharia_civil  1920
# 11                     engenharia_software  1890
# 12                               filosofia  1903
# 13  gestao_da_informacao_e_do_conhecimento  1855

# %%
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                     2017  2018  2019  2020
# CURSO
# ADMINISTRAÇÃO                           2538  2316  1692   269
# ARQUITETURA E URBANISMO                 2209  1917  1818   257
# ARTES CÊNICAS                           2115  2082  1812   229
# BIOINFORMÁTICA                          2190  1914  1825   263
# BIOQUÍMICA                              2294  1944  2057   272
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316  2110  2008   328
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415  2365  2026   303
# CIÊNCIAS DA SAÚDE                       2434  1986  1825   234
# CIÊNCIAS ODONTOLÓGICAS                  2414  2540  2134   352
# DESIGN                                  2272  1838  1841   254
# ENGENHARIA CIVIL                        2399  2089  1989   254
# ENGENHARIA DE SOFTWARE                  2477  2222  1887   264
# FILOSOFIA                               2170  2048  1773   302
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO  2266  1891  1771   252

# %% [markdown]
# ### Unindo tabelas

# %%
previsao_2022.index = emprestimos_pos_graduacao_e_curso_pivot.index
emprestimos_pos_graduacao_e_curso_pivot['2022'] = previsao_2022.iloc[:,1]
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                     2017  2018  2019  2020  2022
# CURSO
# ADMINISTRAÇÃO                           2538  2316  1692   269  1905
# ARQUITETURA E URBANISMO                 2209  1917  1818   257  1896
# ARTES CÊNICAS                           2115  2082  1812   229  1920
# BIOINFORMÁTICA                          2190  1914  1825   263  2302
# BIOQUÍMICA                              2294  1944  2057   272  2090
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316  2110  2008   328  2010
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415  2365  2026   303  1960
# CIÊNCIAS DA SAÚDE                       2434  1986  1825   234  1730
# CIÊNCIAS ODONTOLÓGICAS                  2414  2540  2134   352  2405
# DESIGN                                  2272  1838  1841   254  1900
# ENGENHARIA CIVIL                        2399  2089  1989   254  1920
# ENGENHARIA DE SOFTWARE                  2477  2222  1887   264  1890
# FILOSOFIA                               2170  2048  1773   302  1903
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO  2266  1891  1771   252  1855

# %% [markdown]
# ### Modificando tipo de dado

# %%
emprestimos_pos_graduacao_e_curso_pivot['2022'] = emprestimos_pos_graduacao_e_curso_pivot['2022'].astype('int')

# %% [markdown]
# ### Pivotando tabela

# %%
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                     2017  2018  2019  2020  2022
# CURSO
# ADMINISTRAÇÃO                           2538  2316  1692   269  1905
# ARQUITETURA E URBANISMO                 2209  1917  1818   257  1896
# ARTES CÊNICAS                           2115  2082  1812   229  1920
# BIOINFORMÁTICA                          2190  1914  1825   263  2302
# BIOQUÍMICA                              2294  1944  2057   272  2090
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316  2110  2008   328  2010
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415  2365  2026   303  1960
# CIÊNCIAS DA SAÚDE                       2434  1986  1825   234  1730
# CIÊNCIAS ODONTOLÓGICAS                  2414  2540  2134   352  2405
# DESIGN                                  2272  1838  1841   254  1900
# ENGENHARIA CIVIL                        2399  2089  1989   254  1920
# ENGENHARIA DE SOFTWARE                  2477  2222  1887   264  1890
# FILOSOFIA                               2170  2048  1773   302  1903
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO  2266  1891  1771   252  1855

# %% [markdown]
# ### Criando função para diferença percentual

# %%
def diferenca_percentual_ano_anterior(x,y):
  return round(((x / y * 100) - 100),2)

# %% [markdown]
# ### Calculando a diferença percentual

# %%
percentual_2018 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,1],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,0])
percentual_2019 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,2],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,1])
percentual_2022 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,3],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,2])

# %% [markdown]
# ### Criando DataFrame com as diferenças percentuais

# %%
percentual = pd.DataFrame({'2018':percentual_2018,
                           '2019':percentual_2019,
                           '2022':percentual_2022})
percentual
# Out:
#                                          2018   2019   2022
# CURSO
# ADMINISTRAÇÃO                           -8.75 -26.94 -84.10
# ARQUITETURA E URBANISMO                -13.22  -5.16 -85.86
# ARTES CÊNICAS                           -1.56 -12.97 -87.36
# BIOINFORMÁTICA                         -12.60  -4.65 -85.59
# BIOQUÍMICA                             -15.26   5.81 -86.78
# CIÊNCIA E ENGENHARIA DE MATERIAIS       -8.89  -4.83 -83.67
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          -2.07 -14.33 -85.04
# CIÊNCIAS DA SAÚDE                      -18.41  -8.11 -87.18
# CIÊNCIAS ODONTOLÓGICAS                   5.22 -15.98 -83.51
# DESIGN                                 -19.10   0.16 -86.20
# ENGENHARIA CIVIL                       -12.92  -4.79 -87.23
# ENGENHARIA DE SOFTWARE                 -10.29 -15.08 -86.01
# FILOSOFIA                               -5.62 -13.43 -82.97
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO -16.55  -6.35 -85.77

# %% [markdown]
# ### Formatando dados da tabela

# %%
percentual.reset_index(inplace=True)
percentual.columns = percentual.columns.str.capitalize()
percentual.Curso = percentual.Curso.str.capitalize()

# %%
percentual
# Out:
#                                      Curso   2018   2019   2022
# 0                            Administração  -8.75 -26.94 -84.10
# 1                  Arquitetura e urbanismo -13.22  -5.16 -85.86
# 2                            Artes cênicas  -1.56 -12.97 -87.36
# 3                           Bioinformática -12.60  -4.65 -85.59
# 4                               Bioquímica -15.26   5.81 -86.78
# 5        Ciência e engenharia de materiais  -8.89  -4.83 -83.67
# 6           Ciência, tecnologia e inovação  -2.07 -14.33 -85.04
# 7                        Ciências da saúde -18.41  -8.11 -87.18
# 8                   Ciências odontológicas   5.22 -15.98 -83.51
# 9                                   Design -19.10   0.16 -86.20
# 10                        Engenharia civil -12.92  -4.79 -87.23
# 11                  Engenharia de software -10.29 -15.08 -86.01
# 12                               Filosofia  -5.62 -13.43 -82.97
# 13  Gestão da informação e do conhecimento -16.55  -6.35 -85.77

# %% [markdown]
# ## Criando tabela em HTML

# %% [markdown]
# ### Estruturando formatação da tabela em CSS

# %%
th_props = [
  ('font-size', '1.4rem'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'whitesmoke'),
  ('background-color', '#001692'),
  ('border-radius', '0.25rem'),
  ('box-shadow','0 0 1rem gray')
  ]

td_props = [
  ('font-size', '1rem'),
  ('padding','0.5rem'),
  ('text-align', 'left'),
  ('font-weight', 'bold'),
  ('border-bottom','0.1rem solid lightgray')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# %% [markdown]
# ### Gerando tabela em HTML

# %%
percentual.style.text_gradient(cmap='RdYlGn',low=1, axis=1,vmax=0.1,vmin=0)\
                              .format('{:.2f} %',subset=['2018','2019','2022'])\
                              .hide_index()\
                              .set_table_styles(styles)\
                              .to_html('pos.html',doctype_html =True,
                                       table_attributes='ALIGN=LEFT WIDTH=50% CELLSPACING = 5')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_30488\2493400934.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   .hide_index()\

# %% [markdown]
# ### Importando cadastro de usuários apenas de graduação

# %% [markdown]
# ### Arquivo excel

# %%
cadastro_usuarios_antes_2010 = pd.read_excel('dataset\matricula_alunos.xlsx',
                                        sheet_name='Até 2010',skiprows=1)
cadastro_usuarios_depois_2010 = pd.read_excel('dataset\matricula_alunos.xlsx',
                                        sheet_name='Após 2010',skiprows=1)

# %%
cadastro_usuarios_antes_2010
# Out:
#       Número da matrícula     Tipo de vinculo  \
# 0            1.900017e+08  ALUNO DE GRADUAÇÃO
# 1            1.990145e+08  ALUNO DE GRADUAÇÃO
# 2            1.997357e+08  ALUNO DE GRADUAÇÃO
# 3            1.998124e+08  ALUNO DE GRADUAÇÃO
# 4            1.998237e+08  ALUNO DE GRADUAÇÃO
# ...                   ...                 ...
# 7721         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7722         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7723         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7724         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7725         2.009075e+09  ALUNO DE GRADUAÇÃO
#
#                                       Curso
# 0                                MATEMÁTICA
# 1                       CIÊNCIAS BIOLÓGICAS
# 2                                MATEMÁTICA
# 3                                    LETRAS
# 4                                  ECOLOGIA
# ...                                     ...
# 7721                        BIBLIOTECONOMIA
# 7722  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# 7723                          ADMINISTRAÇÃO
# 7724                                 MÚSICA
# 7725                                DIREITO
#
# [7726 rows x 3 columns]

# %%
cadastro_usuarios_antes_2010.columns = ['matricula_ou_siape','tipo_vinculo_usuario','curso']

# %%
cadastro_usuarios_depois_2010
# Out:
#         Matricula      Tipo de vinculo                    Cursos
# 0     2.010000e+09  ALUNO DE GRADUAÇÃO                   DIREITO
# 1     2.010000e+09  ALUNO DE GRADUAÇÃO                 AGRONOMIA
# 2     2.010001e+09  ALUNO DE GRADUAÇÃO        ENGENHARIA QUÍMICA
# 3     2.010003e+09  ALUNO DE GRADUAÇÃO      ENGENHARIA AMBIENTAL
# 4     2.010003e+09  ALUNO DE GRADUAÇÃO                 GEOGRAFIA
# ...            ...                 ...                       ...
# 2269  2.015012e+10  ALUNO DE GRADUAÇÃO                    LETRAS
# 2270  2.015075e+09  ALUNO DE GRADUAÇÃO                     DANÇA
# 2271  2.016000e+10  ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 2272  2.017009e+10  ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 2273  2.018009e+10  ALUNO DE GRADUAÇÃO                     DANÇA
#
# [2274 rows x 3 columns]

# %%
cadastro_usuarios_depois_2010.columns= ['matricula_ou_siape','tipo_vinculo_usuario','curso']

# %%
cadastro_usuarios_excel = pd.concat([cadastro_usuarios_antes_2010,cadastro_usuarios_depois_2010],ignore_index=True)
cadastro_usuarios_excel.matricula_ou_siape = cadastro_usuarios_excel.matricula_ou_siape.astype('string')
cadastro_usuarios_excel
# Out:
#      matricula_ou_siape tipo_vinculo_usuario                     curso
# 0           190001688.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 1           199014489.0   ALUNO DE GRADUAÇÃO       CIÊNCIAS BIOLÓGICAS
# 2           199735674.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 3           199812431.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 4           199823670.0   ALUNO DE GRADUAÇÃO                  ECOLOGIA
# ...                 ...                  ...                       ...
# 9995      20150116770.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 9996       2015074523.0   ALUNO DE GRADUAÇÃO                     DANÇA
# 9997      20160002745.0   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 9998      20170086533.0   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 9999      20180090351.0   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [10000 rows x 3 columns]

# %% [markdown]
# ### Arquivo JSON

# %%
cadastro_usuarios_json = pd.read_json('dataset\cadastro_alunos.json')
cadastro_usuarios_json
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %%
cadastro_usuarios_graduacao_json = pd.read_json(cadastro_usuarios_json.registros[0])

# %%
cadastro_usuarios_graduacao_json
# Out:
#        matricula_ou_siape tipo_vinculo_usuario                   curso
# 0              2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1               200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2               200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3               200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4               200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO
# ...                   ...                  ...                     ...
# 62797         20200012706   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62798         20200039601   ALUNO DE GRADUAÇÃO    ENGENHARIA FLORESTAL
# 62799         20200132517   ALUNO DE GRADUAÇÃO               AGRONOMIA
# 62800         20200009344   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62801         20200090284   ALUNO DE GRADUAÇÃO                 DIREITO
#
# [62802 rows x 3 columns]

# %%
cadastro_usuarios_graduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  int64
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Modificando tipo de dado da matricula

# %%
cadastro_usuarios_graduacao_json.matricula_ou_siape = cadastro_usuarios_graduacao_json.matricula_ou_siape.astype('float')
cadastro_usuarios_graduacao_json.matricula_ou_siape = cadastro_usuarios_graduacao_json.matricula_ou_siape.astype('string')

# %%
cadastro_usuarios_graduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  string
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: object(2), string(1)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Concatenando arquivos Excel e JSON

# %%
cadastro_usuarios_cursos = pd.concat([cadastro_usuarios_excel,cadastro_usuarios_graduacao_json],ignore_index=True)
cadastro_usuarios_cursos
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                 curso
# 0            190001688.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 1            199014489.0   ALUNO DE GRADUAÇÃO   CIÊNCIAS BIOLÓGICAS
# 2            199735674.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 3            199812431.0   ALUNO DE GRADUAÇÃO                LETRAS
# 4            199823670.0   ALUNO DE GRADUAÇÃO              ECOLOGIA
# ...                  ...                  ...                   ...
# 72797      20200012706.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72798      20200039601.0   ALUNO DE GRADUAÇÃO  ENGENHARIA FLORESTAL
# 72799      20200132517.0   ALUNO DE GRADUAÇÃO             AGRONOMIA
# 72800      20200009344.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72801      20200090284.0   ALUNO DE GRADUAÇÃO               DIREITO
#
# [72802 rows x 3 columns]

# %% [markdown]
# cadastro_usuarios_cursos_pos_graduacao = cadastro_usuarios_posgraduacao_json.query("tipo_vinculo_usuario == 'ALUNO DE PÓS-GRADUAÇÃO'")
# cadastro_usuarios_cursos_pos_graduacao

# %%
cadastro_usuarios_cursos_graduacao = cadastro_usuarios_graduacao_json.query("tipo_vinculo_usuario == 'ALUNO DE GRADUAÇÃO'")
cadastro_usuarios_cursos_graduacao
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                   curso
# 0           2009029003.0   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1            200617346.0   ALUNO DE GRADUAÇÃO                 DIREITO
# 2            200746502.0   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3            200504968.0   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4            200615572.0   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO
# ...                  ...                  ...                     ...
# 62797      20200012706.0   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62798      20200039601.0   ALUNO DE GRADUAÇÃO    ENGENHARIA FLORESTAL
# 62799      20200132517.0   ALUNO DE GRADUAÇÃO               AGRONOMIA
# 62800      20200009344.0   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62801      20200090284.0   ALUNO DE GRADUAÇÃO                 DIREITO
#
# [62802 rows x 3 columns]

# %% [markdown]
# ### Filtrando empréstimos desde de 2017

# %%
matricula_data_de_emprestimo_graduacao = emprestimos_completo.loc[:,['matricula_ou_siape','data_emprestimo']]
matricula_data_de_emprestimo_graduacao = matricula_data_de_emprestimo_graduacao.query('data_emprestimo > 2017')
matricula_data_de_emprestimo_graduacao = matricula_data_de_emprestimo_graduacao.reset_index(drop=True)
matricula_data_de_emprestimo_graduacao
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2013043297.0 2017-02-16 16:39:45.480
# 1           20171029059.0 2017-03-28 09:04:09.781
# 2            2013043297.0 2017-04-24 20:01:50.300
# 3            2016008166.0 2017-06-19 19:59:41.522
# 4           20170083498.0 2017-07-24 08:40:48.277
# ...                   ...                     ...
# 609948      20150109837.0 2020-03-17 19:49:10.187
# 609949      20190035012.0 2020-03-17 19:51:15.700
# 609950      20191021693.0 2020-03-17 20:00:11.416
# 609951      20150129867.0 2020-03-17 20:47:18.741
# 609952      20200005327.0 2020-03-17 21:22:22.138
#
# [609953 rows x 2 columns]

# %% [markdown]
# ### Unindo DataFrames de cadastro de usuários e de empréstimos

# %%
emprestimos_graduacao_desde_2017 = matricula_data_de_emprestimo_graduacao.merge(cadastro_usuarios_cursos_graduacao)
emprestimos_graduacao_desde_2017
# Out:
#        matricula_ou_siape         data_emprestimo tipo_vinculo_usuario  \
# 0            2013043297.0 2017-02-16 16:39:45.480   ALUNO DE GRADUAÇÃO
# 1            2013043297.0 2017-04-24 20:01:50.300   ALUNO DE GRADUAÇÃO
# 2            2013043297.0 2017-03-16 16:37:03.184   ALUNO DE GRADUAÇÃO
# 3            2013043297.0 2017-03-16 16:37:03.246   ALUNO DE GRADUAÇÃO
# 4            2013043297.0 2017-11-16 12:38:31.245   ALUNO DE GRADUAÇÃO
# ...                   ...                     ...                  ...
# 458139      20190067212.0 2020-03-13 21:41:01.524   ALUNO DE GRADUAÇÃO
# 458140      20190067212.0 2020-03-13 21:41:01.560   ALUNO DE GRADUAÇÃO
# 458141      20200047980.0 2020-03-16 10:51:40.709   ALUNO DE GRADUAÇÃO
# 458142      20200048727.0 2020-03-16 14:12:53.090   ALUNO DE GRADUAÇÃO
# 458143      20200000699.0 2020-03-17 12:34:47.730   ALUNO DE GRADUAÇÃO
#
#                          curso
# 0         ENGENHARIA FLORESTAL
# 1         ENGENHARIA FLORESTAL
# 2         ENGENHARIA FLORESTAL
# 3         ENGENHARIA FLORESTAL
# 4         ENGENHARIA FLORESTAL
# ...                        ...
# 458139        CIÊNCIAS SOCIAIS
# 458140        CIÊNCIAS SOCIAIS
# 458141                   DANÇA
# 458142               AGRONOMIA
# 458143  SISTEMAS DE INFORMAÇÃO
#
# [458144 rows x 4 columns]

# %% [markdown]
# ### Modificando tipo de data

# %%
emprestimos_graduacao_desde_2017.data_emprestimo = emprestimos_graduacao_desde_2017.data_emprestimo.dt.year

# %% [markdown]
# ### Contando valores de empréstimos

# %%
emprestimos_graduacao_desde_2017 = emprestimos_graduacao_desde_2017.iloc[:,[1,3]].value_counts().reset_index()
emprestimos_graduacao_desde_2017.columns = ['ANO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimos_graduacao_desde_2017.head()
# Out:
#     ANO                    CURSO  QUANTIDADE_EMPRESTIMOS
# 0  2017       COMUNICAÇÃO SOCIAL                    8239
# 1  2017    CIÊNCIAS E TECNOLOGIA                    8137
# 2  2017       CIÊNCIAS ATUARIAIS                    8054
# 3  2017  ARQUITETURA E URBANISMO                    7986
# 4  2017         ENGENHARIA CIVIL                    7972

# %% [markdown]
# ### Pivotando tabela

# %%
emprestimos_graduacao_e_curso_pivot = emprestimos_graduacao_desde_2017.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS'
)
emprestimos_graduacao_e_curso_pivot
# Out:
# ANO                      2017  2018  2019  2020
# CURSO
# ADMINISTRAÇÃO            7356  6265  5657   766
# AGRONOMIA                7531  6789  5583   830
# ARQUITETURA E URBANISMO  7986  6906  5974   810
# BIBLIOTECONOMIA          7279  6377  5887   900
# BIOMEDICINA              7166  6273  5400   806
# CIÊNCIA DA COMPUTAÇÃO    7033  6408  5498   809
# CIÊNCIAS ATUARIAIS       8054  7235  6384   926
# CIÊNCIAS BIOLÓGICAS      7209  6507  5332   829
# CIÊNCIAS E TECNOLOGIA    8137  6961  6079   924
# CIÊNCIAS SOCIAIS         6896  6181  5788   825
# COMUNICAÇÃO SOCIAL       8239  6950  5885   796
# DANÇA                    7140  6577  5871   881
# DIREITO                  7862  7022  5860   905
# EDUCAÇÃO FÍSICA          7643  6815  5761   854
# ENFERMAGEM               7456  6891  6165   964
# ENGENHARIA CIVIL         7972  6997  6473   851
# ENGENHARIA DE PETRÓLEO   7536  6614  5811   811
# ENGENHARIA FLORESTAL     7418  6785  6111   878
# FILOSOFIA                7389  6296  5572   832
# MATEMÁTICA               7795  6477  5460   777
# PEDAGOGIA                7434  6518  5869   866
# SISTEMAS DE INFORMAÇÃO   6883  6155  5667   804

# %% [markdown]
# ### Importando dados da previsão

# %%
previsao_2022 = pd.read_table('dataset/previsao')

# %% [markdown]
# ### Tratando dados da previsão

# %%
previsao_2022 = previsao_2022['curso previsao_2022'].str.split(' ',expand=True)
previsao_2022
# Out:
#                                          0     1
# 0                            administracao  1905
# 1                  arquitetura_e_urbanismo  1896
# 2                            artes_cenicas  1920
# 3                           bioinformatica  2302
# 4                               bioquimica  2090
# 5        ciencia_e_engenharia_de_materiais  2010
# 6            ciencia_tecnologia_e_inovacao  1960
# 7                        ciencias_da_saude  1730
# 8                   ciencias_odontologicas  2405
# 9                                   design  1900
# 10                        engenharia_civil  1920
# 11                     engenharia_software  1890
# 12                               filosofia  1903
# 13  gestao_da_informacao_e_do_conhecimento  1855

# %%
emprestimos_graduacao_e_curso_pivot
# Out:
# ANO                      2017  2018  2019  2020
# CURSO
# ADMINISTRAÇÃO            7356  6265  5657   766
# AGRONOMIA                7531  6789  5583   830
# ARQUITETURA E URBANISMO  7986  6906  5974   810
# BIBLIOTECONOMIA          7279  6377  5887   900
# BIOMEDICINA              7166  6273  5400   806
# CIÊNCIA DA COMPUTAÇÃO    7033  6408  5498   809
# CIÊNCIAS ATUARIAIS       8054  7235  6384   926
# CIÊNCIAS BIOLÓGICAS      7209  6507  5332   829
# CIÊNCIAS E TECNOLOGIA    8137  6961  6079   924
# CIÊNCIAS SOCIAIS         6896  6181  5788   825
# COMUNICAÇÃO SOCIAL       8239  6950  5885   796
# DANÇA                    7140  6577  5871   881
# DIREITO                  7862  7022  5860   905
# EDUCAÇÃO FÍSICA          7643  6815  5761   854
# ENFERMAGEM               7456  6891  6165   964
# ENGENHARIA CIVIL         7972  6997  6473   851
# ENGENHARIA DE PETRÓLEO   7536  6614  5811   811
# ENGENHARIA FLORESTAL     7418  6785  6111   878
# FILOSOFIA                7389  6296  5572   832
# MATEMÁTICA               7795  6477  5460   777
# PEDAGOGIA                7434  6518  5869   866
# SISTEMAS DE INFORMAÇÃO   6883  6155  5667   804

# %% [markdown]
# ### Unindo tabelas

# %%
previsao_2022.index = emprestimos_graduacao_e_curso_pivot.index
emprestimos_graduacao_e_curso_pivot['2022'] = previsao_2022.iloc[:,1]
emprestimos_graduacao_e_curso_pivot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[320], line 1
# ----> 1 previsao_2022.index = emprestimos_graduacao_e_curso_pivot.index
#       2 emprestimos_graduacao_e_curso_pivot['2022'] = previsao_2022.iloc[:,1]
#       3 emprestimos_graduacao_e_curso_pivot
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\core\generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822     labels = ensure_index(labels)
# --> 823     self._mgr.set_axis(axis, labels)
#     824     self._clear_item_cache()
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:230, in BaseBlockManager.set_axis(self, axis, new_labels)
#     228 def set_axis(self, axis: int, new_labels: Index) -> None:
#     229     # Caller is responsible for ensuring we have an Index object.
# --> 230     self._validate_set_axis(axis, new_labels)
#     231     self.axes[axis] = new_labels
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\core\internals\base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 14 elements, new values have 22 elements

# %% [markdown]
# ### Modificando tipo de dado

# %%
emprestimos_graduacao_e_curso_pivot['2022'] = emprestimos_graduacao_e_curso_pivot['2022'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:146, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:49, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2022'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[319], line 1
# ----> 1 emprestimos_graduacao_e_curso_pivot['2022'] = emprestimos_graduacao_e_curso_pivot['2022'].astype('int')
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: '2022'

# %% [markdown]
# ### Pivotando tabela

# %%
emprestimos_graduacao_e_curso_pivot
# Out:
# ANO                      2017  2018  2019  2020
# CURSO
# ADMINISTRAÇÃO            7356  6265  5657   766
# AGRONOMIA                7531  6789  5583   830
# ARQUITETURA E URBANISMO  7986  6906  5974   810
# BIBLIOTECONOMIA          7279  6377  5887   900
# BIOMEDICINA              7166  6273  5400   806
# CIÊNCIA DA COMPUTAÇÃO    7033  6408  5498   809
# CIÊNCIAS ATUARIAIS       8054  7235  6384   926
# CIÊNCIAS BIOLÓGICAS      7209  6507  5332   829
# CIÊNCIAS E TECNOLOGIA    8137  6961  6079   924
# CIÊNCIAS SOCIAIS         6896  6181  5788   825
# COMUNICAÇÃO SOCIAL       8239  6950  5885   796
# DANÇA                    7140  6577  5871   881
# DIREITO                  7862  7022  5860   905
# EDUCAÇÃO FÍSICA          7643  6815  5761   854
# ENFERMAGEM               7456  6891  6165   964
# ENGENHARIA CIVIL         7972  6997  6473   851
# ENGENHARIA DE PETRÓLEO   7536  6614  5811   811
# ENGENHARIA FLORESTAL     7418  6785  6111   878
# FILOSOFIA                7389  6296  5572   832
# MATEMÁTICA               7795  6477  5460   777
# PEDAGOGIA                7434  6518  5869   866
# SISTEMAS DE INFORMAÇÃO   6883  6155  5667   804

# %% [markdown]
# ### Criando função para diferença percentual

# %%
def diferenca_percentual_ano_anterior(x,y):
  return round(((x / y * 100) - 100),2)

# %% [markdown]
# ### Calculando a diferença percentual

# %%
percentual_2018 = diferenca_percentual_ano_anterior(emprestimos_graduacao_e_curso_pivot.iloc[:,1],emprestimos_graduacao_e_curso_pivot.iloc[:,0])
percentual_2019 = diferenca_percentual_ano_anterior(emprestimos_graduacao_e_curso_pivot.iloc[:,2],emprestimos_graduacao_e_curso_pivot.iloc[:,1])
percentual_2022 = diferenca_percentual_ano_anterior(emprestimos_graduacao_e_curso_pivot.iloc[:,3],emprestimos_graduacao_e_curso_pivot.iloc[:,2])

# %% [markdown]
# ### Criando DataFrame com as diferenças percentuais

# %%
percentual = pd.DataFrame({'2018':percentual_2018,
                           '2019':percentual_2019,
                           '2022':percentual_2022})
percentual
# Out:
#                           2018   2019   2022
# CURSO
# ADMINISTRAÇÃO           -14.83  -9.70 -86.46
# AGRONOMIA                -9.85 -17.76 -85.13
# ARQUITETURA E URBANISMO -13.52 -13.50 -86.44
# BIBLIOTECONOMIA         -12.39  -7.68 -84.71
# BIOMEDICINA             -12.46 -13.92 -85.07
# CIÊNCIA DA COMPUTAÇÃO    -8.89 -14.20 -85.29
# CIÊNCIAS ATUARIAIS      -10.17 -11.76 -85.49
# CIÊNCIAS BIOLÓGICAS      -9.74 -18.06 -84.45
# CIÊNCIAS E TECNOLOGIA   -14.45 -12.67 -84.80
# CIÊNCIAS SOCIAIS        -10.37  -6.36 -85.75
# COMUNICAÇÃO SOCIAL      -15.65 -15.32 -86.47
# DANÇA                    -7.89 -10.73 -84.99
# DIREITO                 -10.68 -16.55 -84.56
# EDUCAÇÃO FÍSICA         -10.83 -15.47 -85.18
# ENFERMAGEM               -7.58 -10.54 -84.36
# ENGENHARIA CIVIL        -12.23  -7.49 -86.85
# ENGENHARIA DE PETRÓLEO  -12.23 -12.14 -86.04
# ENGENHARIA FLORESTAL     -8.53  -9.93 -85.63
# FILOSOFIA               -14.79 -11.50 -85.07
# MATEMÁTICA              -16.91 -15.70 -85.77
# PEDAGOGIA               -12.32  -9.96 -85.24
# SISTEMAS DE INFORMAÇÃO  -10.58  -7.93 -85.81

# %% [markdown]
# ### Formatando dados da tabela

# %%
percentual.reset_index(inplace=True)
percentual.columns = percentual.columns.str.capitalize()
percentual.Curso = percentual.Curso.str.capitalize()

# %%
percentual
# Out:
#                       Curso   2018   2019   2022
# 0             Administração -14.83  -9.70 -86.46
# 1                 Agronomia  -9.85 -17.76 -85.13
# 2   Arquitetura e urbanismo -13.52 -13.50 -86.44
# 3           Biblioteconomia -12.39  -7.68 -84.71
# 4               Biomedicina -12.46 -13.92 -85.07
# 5     Ciência da computação  -8.89 -14.20 -85.29
# 6        Ciências atuariais -10.17 -11.76 -85.49
# 7       Ciências biológicas  -9.74 -18.06 -84.45
# 8     Ciências e tecnologia -14.45 -12.67 -84.80
# 9          Ciências sociais -10.37  -6.36 -85.75
# 10       Comunicação social -15.65 -15.32 -86.47
# 11                    Dança  -7.89 -10.73 -84.99
# 12                  Direito -10.68 -16.55 -84.56
# 13          Educação física -10.83 -15.47 -85.18
# 14               Enfermagem  -7.58 -10.54 -84.36
# 15         Engenharia civil -12.23  -7.49 -86.85
# 16   Engenharia de petróleo -12.23 -12.14 -86.04
# 17     Engenharia florestal  -8.53  -9.93 -85.63
# 18                Filosofia -14.79 -11.50 -85.07
# 19               Matemática -16.91 -15.70 -85.77
# 20                Pedagogia -12.32  -9.96 -85.24
# 21   Sistemas de informação -10.58  -7.93 -85.81

# %% [markdown]
# ## Criando tabela em HTML

# %% [markdown]
# Estruturando formatação da tabela em CSS

# %%
th_props = [
  ('font-size', '1.4rem'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'whitesmoke'),
  ('background-color', '#001692'),
  ('border-radius', '0.25rem'),
  ('box-shadow','0 0 1rem gray')
  ]

td_props = [
  ('font-size', '1rem'),
  ('padding','0.5rem'),
  ('text-align', 'left'),
  ('font-weight', 'bold'),
  ('border-bottom','0.1rem solid lightgray')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# %% [markdown]
# ### Gerando tabela em HTML

# %%
percentual.style.text_gradient(cmap='RdYlGn',low=1, axis=1,vmax=0.1,vmin=0)\
                              .format('{:.2f} %',subset=['2018','2019','2022'])\
                              .hide_index()\
                              .set_table_styles(styles)\
                              .to_html('grad.html',doctype_html =True,
                                       table_attributes='ALIGN=LEFT WIDTH=50% CELLSPACING = 5')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_30488\1069888844.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   .hide_index()\
